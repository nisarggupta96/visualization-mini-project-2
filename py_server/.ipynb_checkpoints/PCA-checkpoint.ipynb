# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %%
cols_to_drop = ["name", "torque", "fuel", "seller_type", "transmission", "owner"]
df_1 = df.drop(cols_to_drop, axis=1)
df_1 = df_1.dropna(axis=0)
df_1
# Out:
#       year  selling_price  km_driven     mileage   engine   max_power  seats
# 0     2014         450000     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1     2014         370000     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2     2006         158000     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3     2010         225000     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4     2007         130000     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ...    ...            ...        ...         ...      ...         ...    ...
# 8123  2013         320000     110000   18.5 kmpl  1197 CC   82.85 bhp    5.0
# 8124  2007         135000     119000   16.8 kmpl  1493 CC     110 bhp    5.0
# 8125  2009         382000     120000   19.3 kmpl  1248 CC    73.9 bhp    5.0
# 8126  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
# 8127  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
#
# [7907 rows x 7 columns]

# %%
df_2 = df_1.replace(np.nan,0,regex=True)
df_2 = df_1.replace('',0,regex=True)
df_2
# Out:
#       year  selling_price  km_driven     mileage   engine   max_power  seats
# 0     2014         450000     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1     2014         370000     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2     2006         158000     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3     2010         225000     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4     2007         130000     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ...    ...            ...        ...         ...      ...         ...    ...
# 8123  2013         320000     110000   18.5 kmpl  1197 CC   82.85 bhp    5.0
# 8124  2007         135000     119000   16.8 kmpl  1493 CC     110 bhp    5.0
# 8125  2009         382000     120000   19.3 kmpl  1248 CC    73.9 bhp    5.0
# 8126  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
# 8127  2013         290000      25000  23.57 kmpl  1396 CC      70 bhp    5.0
#
# [7907 rows x 7 columns]

# %%
df_2['engine'] = df_2['engine'].apply(lambda x: '0' + x.replace(' CC', ''))
df_2['engine'] = df_2['engine'].astype('float')
df_2
# Out:
#       year  selling_price  km_driven     mileage  engine   max_power  seats
# 0     2014         450000     145500   23.4 kmpl  1248.0      74 bhp    5.0
# 1     2014         370000     120000  21.14 kmpl  1498.0  103.52 bhp    5.0
# 2     2006         158000     140000   17.7 kmpl  1497.0      78 bhp    5.0
# 3     2010         225000     127000   23.0 kmpl  1396.0      90 bhp    5.0
# 4     2007         130000     120000   16.1 kmpl  1298.0    88.2 bhp    5.0
# ...    ...            ...        ...         ...     ...         ...    ...
# 8123  2013         320000     110000   18.5 kmpl  1197.0   82.85 bhp    5.0
# 8124  2007         135000     119000   16.8 kmpl  1493.0     110 bhp    5.0
# 8125  2009         382000     120000   19.3 kmpl  1248.0    73.9 bhp    5.0
# 8126  2013         290000      25000  23.57 kmpl  1396.0      70 bhp    5.0
# 8127  2013         290000      25000  23.57 kmpl  1396.0      70 bhp    5.0
#
# [7907 rows x 7 columns]

# %%
df_2['max_power'] = df_2['max_power'].apply(lambda x: '0' + x.replace(' bhp', ''))
df_2['max_power'] = df_2['max_power'].astype('float')
df_2
# Out:
#       year  selling_price  km_driven     mileage  engine  max_power  seats
# 0     2014         450000     145500   23.4 kmpl  1248.0      74.00    5.0
# 1     2014         370000     120000  21.14 kmpl  1498.0     103.52    5.0
# 2     2006         158000     140000   17.7 kmpl  1497.0      78.00    5.0
# 3     2010         225000     127000   23.0 kmpl  1396.0      90.00    5.0
# 4     2007         130000     120000   16.1 kmpl  1298.0      88.20    5.0
# ...    ...            ...        ...         ...     ...        ...    ...
# 8123  2013         320000     110000   18.5 kmpl  1197.0      82.85    5.0
# 8124  2007         135000     119000   16.8 kmpl  1493.0     110.00    5.0
# 8125  2009         382000     120000   19.3 kmpl  1248.0      73.90    5.0
# 8126  2013         290000      25000  23.57 kmpl  1396.0      70.00    5.0
# 8127  2013         290000      25000  23.57 kmpl  1396.0      70.00    5.0
#
# [7907 rows x 7 columns]

# %%
df_2['mileage'] = df_2['mileage'].apply(lambda x: '0' + x.replace(' kmpl', '').replace(' km/kg', ''))
df_2['mileage'] = df_2['mileage'].astype('float')
df_2
# Out:
#       year  selling_price  km_driven  mileage  engine  max_power  seats
# 0     2014         450000     145500    23.40  1248.0      74.00    5.0
# 1     2014         370000     120000    21.14  1498.0     103.52    5.0
# 2     2006         158000     140000    17.70  1497.0      78.00    5.0
# 3     2010         225000     127000    23.00  1396.0      90.00    5.0
# 4     2007         130000     120000    16.10  1298.0      88.20    5.0
# ...    ...            ...        ...      ...     ...        ...    ...
# 8123  2013         320000     110000    18.50  1197.0      82.85    5.0
# 8124  2007         135000     119000    16.80  1493.0     110.00    5.0
# 8125  2009         382000     120000    19.30  1248.0      73.90    5.0
# 8126  2013         290000      25000    23.57  1396.0      70.00    5.0
# 8127  2013         290000      25000    23.57  1396.0      70.00    5.0
#
# [7907 rows x 7 columns]

# %%
df_2["selling_price"] = pd.qcut(df_2["selling_price"], 4, labels=["Grp 1", "Grp 2", "Grp 3", "Grp 4"])
df_2["selling_price"]
# Out:
# 0       Grp 2
# 1       Grp 2
# 2       Grp 1
# 3       Grp 1
# 4       Grp 1
#         ...
# 8123    Grp 2
# 8124    Grp 1
# 8125    Grp 2
# 8126    Grp 2
# 8127    Grp 2
# Name: selling_price, Length: 7907, dtype: category
# Categories (4, object): ['Grp 1' < 'Grp 2' < 'Grp 3' < 'Grp 4']

# %%
scaler = StandardScaler()
scaled_df = df_2.copy()
numeric_columns = ["year", "km_driven", "mileage", "engine", "max_power", "seats"]

scaled_df[numeric_columns] = scaler.fit_transform(scaled_df[numeric_columns])
scaled_df
# Out:
#           year selling_price  km_driven   mileage    engine  max_power  \
# 0     0.004612         Grp 2   1.343768  0.986209 -0.418003  -0.491527
# 1     0.004612         Grp 2   0.894715  0.426372  0.078143   0.334033
# 2    -2.064493         Grp 1   1.246914 -0.425769  0.076158  -0.379662
# 3    -1.029940         Grp 1   1.017985  0.887123 -0.124284  -0.044069
# 4    -1.805855         Grp 1   0.894715 -0.822114 -0.318774  -0.094408
# ...        ...           ...        ...       ...       ...        ...
# 8123 -0.254026         Grp 2   0.718616 -0.227597 -0.519216  -0.244027
# 8124 -1.805855         Grp 1   0.877105 -0.648713  0.068220   0.515254
# 8125 -1.288579         Grp 2   0.894715 -0.029424 -0.418003  -0.494324
# 8126 -0.254026         Grp 2  -0.778227  1.028321 -0.124284  -0.603392
# 8127 -0.254026         Grp 2  -0.778227  1.028321 -0.124284  -0.603392
#
#          seats
# 0    -0.434297
# 1    -0.434297
# 2    -0.434297
# 3    -0.434297
# 4    -0.434297
# ...        ...
# 8123 -0.434297
# 8124 -0.434297
# 8125 -0.434297
# 8126 -0.434297
# 8127 -0.434297
#
# [7907 rows x 7 columns]

# %%
# columns_to_encode = ["fuel", "seller_type", "transmission", "owner"]

# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()

# scaled_df[columns_to_encode] = scaled_df[columns_to_encode].apply(le.fit_transform)
# scaled_df

# %%
from sklearn.decomposition import PCA

#define PCA model to use
pca_model = PCA(n_components=4)

#fit PCA model to data
res = pca_model.fit_transform(scaled_df[numeric_columns])

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

plt.bar(range(1,len(pca_model.explained_variance_ratio_ )+1), pca_model.explained_variance_ratio_ )
plt.ylabel('Explained variance')
plt.xlabel('Components')
plt.plot(range(1,len(pca_model.explained_variance_ratio_ )+1),
         np.cumsum(pca_model.explained_variance_ratio_),
         c='red',
         label="Cumulative Explained Variance")
plt.legend(loc='upper left')

# %%
plt.plot(pca_model.explained_variance_ratio_)
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

#PCA1 is at 0 in xscale

# %%
print(pd.DataFrame(pca_model.components_[0:2].T, index=scaled_df[numeric_columns].columns))
# Out:
#                   0         1
# year      -0.097708 -0.686044
# km_driven  0.213709  0.550979
# mileage   -0.489156 -0.146327
# engine     0.574413 -0.166354
# max_power  0.414456 -0.419347
# seats      0.451424  0.028796

# %%
plt.scatter(res[:, 0], res[:, 1])

# %%
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=2)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))

myplot(res[:,0:2],np.transpose(pca_model.components_[0:2, :]),list(scaled_df[numeric_columns].columns))
plt.show()

# %%
res
# Out:
# array([[-0.83555911,  0.85606619,  0.66977436,  1.21968928],
#        [-0.03052762,  0.26183428,  0.02181975,  1.10301643],
#        [ 0.36680225,  2.29969163, -0.78726104,  0.39267465],
#        ...,
#        [-0.30952751,  1.64561945, -0.39090315,  0.31387825],
#        [-1.16202515, -0.14378528, -0.02294135, -0.22008559],
#        [-1.16202515, -0.14378528, -0.02294135, -0.22008559]])

# %%
sns.pairplot(
    scaled_df,
    x_vars=["year", "seats", "km_driven", "engine"],
    y_vars=["engine", "km_driven", "seats", "year"],
    hue="selling_price",
    markers=["o", "s", "D", "X"]
)

# %%
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=2, c=)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))

myplot(res[:,0:2],np.transpose(pca_model.components_[0:2, :]), list(scaled_df[numeric_columns].columns))
plt.show()
