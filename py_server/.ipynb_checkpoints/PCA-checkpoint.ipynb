# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('cars.csv')

# %%
cols_to_drop = ["name", "torque", "fuel", "seller_type", "transmission", "owner"]
df_1 = df.drop(cols_to_drop, axis=1)
df_1 = df_1.dropna(axis=0)
df_1
# Out:
#      year  selling_price  km_driven     mileage   engine   max_power  seats
# 0    2014         450000     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1    2014         370000     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2    2006         158000     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3    2010         225000     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4    2007         130000     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ..    ...            ...        ...         ...      ...         ...    ...
# 995  2013         350000      40000  20.51 kmpl   998 CC   67.04 bhp    5.0
# 996  2008         100000      40000   16.8 kmpl  1405 CC      62 bhp    5.0
# 997  2012         325000     120000  13.93 kmpl  2179 CC  138.03 bhp    7.0
# 998  2012         220000     360003   18.9 kmpl   998 CC    67.1 bhp    5.0
# 999  1999          55000      60000   16.1 kmpl   796 CC      37 bhp    4.0
#
# [971 rows x 7 columns]

# %%
df_2 = df_1.replace(np.nan,0,regex=True)
df_2 = df_1.replace('',0,regex=True)
df_2
# Out:
#      year  selling_price  km_driven     mileage   engine   max_power  seats
# 0    2014         450000     145500   23.4 kmpl  1248 CC      74 bhp    5.0
# 1    2014         370000     120000  21.14 kmpl  1498 CC  103.52 bhp    5.0
# 2    2006         158000     140000   17.7 kmpl  1497 CC      78 bhp    5.0
# 3    2010         225000     127000   23.0 kmpl  1396 CC      90 bhp    5.0
# 4    2007         130000     120000   16.1 kmpl  1298 CC    88.2 bhp    5.0
# ..    ...            ...        ...         ...      ...         ...    ...
# 995  2013         350000      40000  20.51 kmpl   998 CC   67.04 bhp    5.0
# 996  2008         100000      40000   16.8 kmpl  1405 CC      62 bhp    5.0
# 997  2012         325000     120000  13.93 kmpl  2179 CC  138.03 bhp    7.0
# 998  2012         220000     360003   18.9 kmpl   998 CC    67.1 bhp    5.0
# 999  1999          55000      60000   16.1 kmpl   796 CC      37 bhp    4.0
#
# [971 rows x 7 columns]

# %%
df_2['engine'] = df_2['engine'].apply(lambda x: '0' + x.replace(' CC', ''))
df_2['engine'] = df_2['engine'].astype('float')
df_2
# Out:
#      year  selling_price  km_driven     mileage  engine   max_power  seats
# 0    2014         450000     145500   23.4 kmpl  1248.0      74 bhp    5.0
# 1    2014         370000     120000  21.14 kmpl  1498.0  103.52 bhp    5.0
# 2    2006         158000     140000   17.7 kmpl  1497.0      78 bhp    5.0
# 3    2010         225000     127000   23.0 kmpl  1396.0      90 bhp    5.0
# 4    2007         130000     120000   16.1 kmpl  1298.0    88.2 bhp    5.0
# ..    ...            ...        ...         ...     ...         ...    ...
# 995  2013         350000      40000  20.51 kmpl   998.0   67.04 bhp    5.0
# 996  2008         100000      40000   16.8 kmpl  1405.0      62 bhp    5.0
# 997  2012         325000     120000  13.93 kmpl  2179.0  138.03 bhp    7.0
# 998  2012         220000     360003   18.9 kmpl   998.0    67.1 bhp    5.0
# 999  1999          55000      60000   16.1 kmpl   796.0      37 bhp    4.0
#
# [971 rows x 7 columns]

# %%
df_2['max_power'] = df_2['max_power'].apply(lambda x: '0' + x.replace(' bhp', ''))
df_2['max_power'] = df_2['max_power'].astype('float')
df_2
# Out:
#      year  selling_price  km_driven     mileage  engine  max_power  seats
# 0    2014         450000     145500   23.4 kmpl  1248.0      74.00    5.0
# 1    2014         370000     120000  21.14 kmpl  1498.0     103.52    5.0
# 2    2006         158000     140000   17.7 kmpl  1497.0      78.00    5.0
# 3    2010         225000     127000   23.0 kmpl  1396.0      90.00    5.0
# 4    2007         130000     120000   16.1 kmpl  1298.0      88.20    5.0
# ..    ...            ...        ...         ...     ...        ...    ...
# 995  2013         350000      40000  20.51 kmpl   998.0      67.04    5.0
# 996  2008         100000      40000   16.8 kmpl  1405.0      62.00    5.0
# 997  2012         325000     120000  13.93 kmpl  2179.0     138.03    7.0
# 998  2012         220000     360003   18.9 kmpl   998.0      67.10    5.0
# 999  1999          55000      60000   16.1 kmpl   796.0      37.00    4.0
#
# [971 rows x 7 columns]

# %%
df_2['mileage'] = df_2['mileage'].apply(lambda x: '0' + x.replace(' kmpl', '').replace(' km/kg', ''))
df_2['mileage'] = df_2['mileage'].astype('float')
df_2
# Out:
#      year  selling_price  km_driven  mileage  engine  max_power  seats
# 0    2014         450000     145500    23.40  1248.0      74.00    5.0
# 1    2014         370000     120000    21.14  1498.0     103.52    5.0
# 2    2006         158000     140000    17.70  1497.0      78.00    5.0
# 3    2010         225000     127000    23.00  1396.0      90.00    5.0
# 4    2007         130000     120000    16.10  1298.0      88.20    5.0
# ..    ...            ...        ...      ...     ...        ...    ...
# 995  2013         350000      40000    20.51   998.0      67.04    5.0
# 996  2008         100000      40000    16.80  1405.0      62.00    5.0
# 997  2012         325000     120000    13.93  2179.0     138.03    7.0
# 998  2012         220000     360003    18.90   998.0      67.10    5.0
# 999  1999          55000      60000    16.10   796.0      37.00    4.0
#
# [971 rows x 7 columns]

# %%
# df_2["selling_price"] = pd.qcut(df_2["selling_price"], 4, labels=["Grp 1", "Grp 2", "Grp 3", "Grp 4"])
# df_2["selling_price"]

# %%
scaler = StandardScaler()
df_scaled = df_2.copy()
numeric_columns = ["year", "selling_price", "km_driven", "mileage", "engine", "max_power", "seats"]

df_scaled[numeric_columns] = scaler.fit_transform(df_scaled[numeric_columns])
df_scaled
# Out:
#          year  selling_price  km_driven   mileage    engine  max_power  \
# 0    0.021376      -0.220061   1.677345  1.039199 -0.390662  -0.449096
# 1    0.021376      -0.313668   1.120303  0.476487  0.085906   0.347371
# 2   -2.135123      -0.561727   1.557198 -0.380031  0.084000  -0.341174
# 3   -1.056873      -0.483331   1.273216  0.939604 -0.108534  -0.017407
# 4   -1.865561      -0.594490   1.120303 -0.778411 -0.295348  -0.065972
# ..        ...            ...        ...       ...       ...        ...
# 995 -0.248186      -0.337070  -0.627281  0.319625 -0.867229  -0.636881
# 996 -1.595998      -0.629593  -0.627281 -0.604120 -0.091377  -0.772863
# 997 -0.517749      -0.366322   1.120303 -1.318714  1.384075   1.278470
# 998 -0.517749      -0.489182   6.363118 -0.081245 -0.867229  -0.635262
# 999 -4.022060      -0.682247  -0.190385 -0.778411 -1.252295  -1.447377
#
#         seats
# 0   -0.453912
# 1   -0.453912
# 2   -0.453912
# 3   -0.453912
# 4   -0.453912
# ..        ...
# 995 -0.453912
# 996 -0.453912
# 997  1.615329
# 998 -0.453912
# 999 -1.488532
#
# [971 rows x 7 columns]

# %%
# columns_to_encode = ["fuel", "seller_type", "transmission", "owner"]

# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()

# df_scaled[columns_to_encode] = df_scaled[columns_to_encode].apply(le.fit_transform)
# df_scaled

# %%
from sklearn.decomposition import PCA

#define PCA model to use
pca_model = PCA(n_components=4)

#fit PCA model to data
res = pca_model.fit_transform(df_scaled[numeric_columns])

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

plt.bar(range(1,len(pca_model.explained_variance_ratio_ )+1), pca_model.explained_variance_ratio_ )
plt.ylabel('Explained variance')
plt.xlabel('Components')
plt.plot(range(1,len(pca_model.explained_variance_ratio_ )+1),
         np.cumsum(pca_model.explained_variance_ratio_),
         c='red',
         label="Cumulative Explained Variance")
plt.legend(loc='upper left')

# %%
plt.plot(pca_model.explained_variance_ratio_)
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

#PCA1 is at 0 in xscale

# %%
print(pd.DataFrame(pca_model.components_[0:2].T, index=df_scaled[numeric_columns].columns))
# Out:
#                       0         1
# year           0.028057  0.537325
# selling_price  0.364000  0.454737
# km_driven      0.114965 -0.509738
# mileage       -0.406006  0.293256
# engine         0.561989 -0.079492
# max_power      0.484426  0.288163
# seats          0.371698 -0.263263

# %%
plt.scatter(res[:, 0], res[:, 1])

# %%
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=2)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))

myplot(res[:,0:2],np.transpose(pca_model.components_[0:2, :]),list(df_scaled[numeric_columns].columns))
plt.show()

# %%
res
# Out:
# array([[-0.91440558, -0.61769846,  0.58876771,  1.65129895],
#        [-0.13039995, -0.34970986,  0.63747069,  0.9839957 ],
#        [-0.2178405 , -2.29339606,  1.54804975,  0.09965625],
#        ...,
#        [ 2.5139073 , -1.56943257, -0.28103891,  0.17535671],
#        [-0.39189272, -3.76261933,  2.01362331,  3.81175232],
#        [-2.02524209, -2.52828283,  2.38373336, -2.19852614]])

# %%
sns.pairplot(
    df_scaled,
    x_vars=["year", "seats", "km_driven", "engine", "selling_price"],
    y_vars=["selling_price", "engine", "km_driven", "seats", "year"],
)

# %%
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=2)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))

myplot(res[:,0:2],np.transpose(pca_model.components_[0:2, :]), list(df_scaled[numeric_columns].columns))
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "random_state": 1,
    "max_iter": 300,
}

#create list to hold SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(df_scaled[numeric_columns])
    sse.append(kmeans.inertia_)

#visualize results
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kmeans_pca = KMeans(n_clusters = 4, init="k-means++", random_state = 6)

# %%
kmeans_pca.fit(res)
# Out:
# KMeans(n_clusters=4, random_state=6)

# %%
df_pca_kmeans = pd.concat([df_scaled.reset_index(drop=True), pd.DataFrame(res)], axis = 1)

# %%
df_pca_kmeans.columns.values[-3:] = ['Component 1', 'Component 2', 'Component 3']
df_pca_kmeans['Segment PCA'] = kmeans_pca.labels_

# %%
df_pca_kmeans
# Out:
#          year  selling_price  km_driven   mileage    engine  max_power  \
# 0    0.021376      -0.220061   1.677345  1.039199 -0.390662  -0.449096
# 1    0.021376      -0.313668   1.120303  0.476487  0.085906   0.347371
# 2   -2.135123      -0.561727   1.557198 -0.380031  0.084000  -0.341174
# 3   -1.056873      -0.483331   1.273216  0.939604 -0.108534  -0.017407
# 4   -1.865561      -0.594490   1.120303 -0.778411 -0.295348  -0.065972
# ..        ...            ...        ...       ...       ...        ...
# 966 -0.248186      -0.337070  -0.627281  0.319625 -0.867229  -0.636881
# 967 -1.595998      -0.629593  -0.627281 -0.604120 -0.091377  -0.772863
# 968 -0.517749      -0.366322   1.120303 -1.318714  1.384075   1.278470
# 969 -0.517749      -0.489182   6.363118 -0.081245 -0.867229  -0.635262
# 970 -4.022060      -0.682247  -0.190385 -0.778411 -1.252295  -1.447377
#
#         seats         0  Component 1  Component 2  Component 3  Segment PCA
# 0   -0.453912 -0.914406    -0.617698     0.588768     1.651299            1
# 1   -0.453912 -0.130400    -0.349710     0.637471     0.983996            1
# 2   -0.453912 -0.217841    -2.293396     1.548050     0.099656            1
# 3   -0.453912 -0.678839    -1.038026     1.091487     1.055896            1
# 4   -0.453912 -0.190560    -1.948119     1.379622    -0.423454            1
# ..        ...       ...          ...          ...          ...          ...
# 966 -0.453912 -1.296155     0.131756    -0.002572    -0.508588            3
# 967 -0.453912 -0.695257    -1.097231     0.498084    -1.410793            1
# 968  1.615329  2.513907    -1.569433    -0.281039     0.175357            0
# 969 -0.453912 -0.391893    -3.762619     2.013623     3.811752            1
# 970 -1.488532 -2.025242    -2.528283     2.383733    -2.198526            1
#
# [971 rows x 12 columns]

# %%
sns.scatterplot(
    data=df_pca_kmeans,
    x='Component 1',
    y ='Component 2',
    hue = df_pca_kmeans['Segment PCA'],
    palette = ['g', 'r', 'c', 'm']
)
# Out:
# <AxesSubplot: xlabel='Component 1', ylabel='Component 2'>
